# %% [markdown]
# ## EMPLOYEE SAMPLE DATA

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"C:\Users\User\Downloads\Employee Sample Data.xlsx", index_col = 'EEID')

# %%
df.head()
# Out:
#               Full Name                 Job Title Department  \
# EEID
# E02387      Emily Davis                Sr. Manger         IT
# E04105    Theodore Dinh       Technical Architect         IT
# E02572     Luna Sanders                  Director    Finance
# E02832  Penelope Jordan  Computer Systems Manager         IT
# E01639        Austin Vo               Sr. Analyst    Finance
#
#                  Business Unit  Gender  Ethnicity  Age  Hire Date  \
# EEID
# E02387  Research & Development  Female      Black   55 2016-04-08
# E04105           Manufacturing    Male      Asian   59 1997-11-29
# E02572     Speciality Products  Female  Caucasian   50 2006-10-26
# E02832           Manufacturing  Female  Caucasian   26 2019-09-27
# E01639           Manufacturing    Male      Asian   55 1995-11-20
#
#         Annual Salary  Bonus %        Country       City  Exit Date
# EEID
# E02387         141604     0.15  United States    Seattle 2021-10-16
# ...

# %%
filtered_age = df[df['Age'] < 30]
filtered_age
# Out:
#               Full Name                 Job Title   Department  \
# EEID
# E02832  Penelope Jordan  Computer Systems Manager           IT
# E01550      Ruby Barnes                   Manager           IT
# E04332      Luke Martin                   Analyst      Finance
# E04533    Easton Bailey                   Manager   Accounting
# E03344    Camila Rogers         Controls Engineer  Engineering
# ...                 ...                       ...          ...
# E03278    Nicholas Wong                  Director        Sales
# E02558  Jose Richardson                  Director    Marketing
# E02221   Julian Delgado           Systems Analyst           IT
# E00785     Hannah Hoang                   Manager   Accounting
# E02191        Maria Sun                  Director        Sales
#
#                  Business Unit  Gender  Ethnicity  Age  Hire Date  \
# EEID
# E02832           Manufacturing  Female  Caucasian   26 2019-09-27
# ...

# %%
df.isnull()
# Out:
#         Full Name  Job Title  Department  Business Unit  Gender  Ethnicity  \
# EEID
# E02387      False      False       False          False   False      False
# E04105      False      False       False          False   False      False
# E02572      False      False       False          False   False      False
# E02832      False      False       False          False   False      False
# E01639      False      False       False          False   False      False
# ...           ...        ...         ...            ...     ...        ...
# E03094      False      False       False          False   False      False
# E01909      False      False       False          False   False      False
# E04398      False      False       False          False   False      False
# E02521      False      False       False          False   False      False
# E03545      False      False       False          False   False      False
#
# ...

# %%
df.shape
# Out:
# (1000, 13)

# %%
df.size
# Out:
# 13000

# %%
df.describe()
# Out:
#                Age  Annual Salary      Bonus %
# count  1000.000000    1000.000000  1000.000000
# mean     44.382000  113217.365000     0.088660
# std      11.246981   53545.985644     0.117856
# min      25.000000   40063.000000     0.000000
# 25%      35.000000   71430.250000     0.000000
# 50%      45.000000   96557.000000     0.000000
# 75%      54.000000  150782.250000     0.150000
# max      65.000000  258498.000000     0.400000

# %%
age = df['Age']
department = df['Department']

# plt.figure(figsize = (5,5))

plt.bar(age, department)
# Out:
# <BarContainer object of 1000 artists>

# %%
plt.plot(age, department)
